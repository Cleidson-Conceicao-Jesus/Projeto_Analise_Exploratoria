# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Análise Exploratória de Dados de Logística II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Manipulação;</li>
#   <li>Visualização;</li>
#   <li>Storytelling.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Este *notebook* deve servir como um guia para **você continuar** a construção da sua própria análise exploratória de dados. Fique a vontade para copiar os códigos da aula mas busque explorar os dados ao máximo. Por fim, publique seu *notebook* no [Kaggle](https://www.kaggle.com/).

# %% [markdown]
# ---

# %% [markdown]
# # **Análise Exploratória de Dados de Logística**

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# O Loggi Benchmark for Urban Deliveries (BUD) é um repositório do GitHub ([link](https://github.com/loggi/loggibud)) com dados e códigos para problemas típicos que empresas de logística enfrentam: otimização das rotas de entrega, alocação de entregas nos veículos da frota com capacidade limitada, etc. Os dados são sintetizados de fontes públicas (IBGE, IPEA, etc.) e são representativos dos desafios que a startup enfrenta no dia a dia, especialmente com relação a sua escala.
#
# Neste projeto, foram analisados os dados relacionados ao Distrito Federal.

# %% [markdown]
# ## 2\. Pacotes e bibliotecas

# %%
# Instalando biblioteca geopandas
# !pip3 install geopandas

# %%
# Instalando as bibliotecas que serão usados neste projeto
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import geopandas
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ## 3\. Exploração de dados

# %%
# Baixando os arquivos
# !wget -q "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries.json" -O deliveries.json
# !wget -q "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries-geodata.csv" -O deliveries-geodata.csv
# !wget -q "https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bc100/go_df/versao2016/shapefile/bc100_go_df_shp.zip" -O distrito-federal.zip
# !unzip -q distrito-federal.zip -d ./maps
# !cp ./maps/LIM_Unidade_Federacao_A.shp ./distrito-federal.shp
# !cp ./maps/LIM_Unidade_Federacao_A.shx ./distrito-federal.shx

# %%
# Extraindo as informações de entregas de um arquivo json e carregando em um dict python
with open(file='deliveries.json', mode='r', encoding='utf8') as file:
  data = json.load(file)

# Transformando o dict python em um DataFrame do pandas
deliveries_df = pd.DataFrame(data)

# Visualizando o DataFrame
deliveries_df.head()
# Out:
#            name region                                             origin  \
# 0  cvrp-2-df-33   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 1  cvrp-2-df-73   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 2  cvrp-2-df-20   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 3  cvrp-1-df-71   df-1  {'lng': -47.89366206897872, 'lat': -15.8051175...
# 4  cvrp-2-df-87   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
#
#    vehicle_capacity                                         deliveries
# 0               180  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1               180  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2               180  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3               180  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4               180  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...

# %% [markdown]
# ## 4\. Wrangling Da Estrutura

# %%
# Normalizando a coluna origin (gera um novo dataframe com as informações da coluna "origin" separadas em colunas)
hub_origin_df = pd.json_normalize(deliveries_df['origin'])
hub_origin_df.head()
# Out:
#          lng        lat
# 0 -48.054989 -15.838145
# 1 -48.054989 -15.838145
# 2 -48.054989 -15.838145
# 3 -47.893662 -15.805118
# 4 -48.054989 -15.838145

# %%
# Mesclando os DataFrames com o método merge do pandas por um inner join através dos index
deliveries_df = pd.merge(left=deliveries_df, right=hub_origin_df, how='inner', left_index=True, right_index=True)

deliveries_df.head()
# Out:
#            name region                                             origin  \
# 0  cvrp-2-df-33   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 1  cvrp-2-df-73   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 2  cvrp-2-df-20   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 3  cvrp-1-df-71   df-1  {'lng': -47.89366206897872, 'lat': -15.8051175...
# 4  cvrp-2-df-87   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
#
#    vehicle_capacity                                         deliveries  \
# 0               180  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1               180  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2               180  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3               180  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4               180  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...
#
#          lng        lat
# 0 -48.054989 -15.838145
# 1 -48.054989 -15.838145
# ...

# %%
# Excluindo a coluna 'origin' do DataFrame
deliveries_df = deliveries_df.drop('origin', axis=1)

# Reorganizando as colunas
deliveries_df = deliveries_df[["name", "region", "lng", "lat", "vehicle_capacity", "deliveries"]]
deliveries_df.head()
# Out:
#            name region        lng        lat  vehicle_capacity  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180
# 1  cvrp-2-df-73   df-2 -48.054989 -15.838145               180
# 2  cvrp-2-df-20   df-2 -48.054989 -15.838145               180
# 3  cvrp-1-df-71   df-1 -47.893662 -15.805118               180
# 4  cvrp-2-df-87   df-2 -48.054989 -15.838145               180
#
#                                           deliveries
# 0  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...

# %%
#Selecionando e renomeando as colunas adicionadas no DataFrame
deliveries_df.rename(columns={"lng": "hub_lng", "lat": "hub_lat"}, inplace=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat  vehicle_capacity  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180
# 1  cvrp-2-df-73   df-2 -48.054989 -15.838145               180
# 2  cvrp-2-df-20   df-2 -48.054989 -15.838145               180
# 3  cvrp-1-df-71   df-1 -47.893662 -15.805118               180
# 4  cvrp-2-df-87   df-2 -48.054989 -15.838145               180
#
#                                           deliveries
# 0  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...

# %%
# Aplicando o método "explode" à coluna "deliveries", mantendo os registro em cada linha mantendo seu index original
deliveries_exploded_df = deliveries_df[['deliveries']].explode('deliveries')
deliveries_exploded_df.head()
# Out:
#                                           deliveries
# 0  {'id': '313483a19d2f8d65cd5024c8d215cfbd', 'po...
# 0  {'id': '320c94b17aa685c939b3f3244c3099de', 'po...
# 0  {'id': '3663b42f4b8decb33059febaba46d5c8', 'po...
# 0  {'id': 'e11ab58363c38d6abc90d5fba87b7d7', 'poi...
# 0  {'id': '54cb45b7bbbd4e34e7150900f92d7f4b', 'po...

# %%
# Criando um DataFrame diferente com uma coluna de cada informação e concatenando em um único DataFrame
deliveries_normalized_df = pd.concat([
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["size"])).rename(columns={"deliveries": "delivery_size"}),
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lng"])).rename(columns={"deliveries": "delivery_lng"}),
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lat"])).rename(columns={"deliveries": "delivery_lat"}),
], axis= 1)
deliveries_normalized_df.head()
# Out:
#    delivery_size  delivery_lng  delivery_lat
# 0              9    -48.116189    -15.848929
# 0              2    -48.118195    -15.850772
# 0              1    -48.112483    -15.847871
# 0              2    -48.118023    -15.846471
# 0              7    -48.114898    -15.858055

# %%
# Excluindo a coluna "deliveries" original
deliveries_df = deliveries_df.drop("deliveries", axis=1)

# Mesclando o novo DataFrame deliveries_normalized_df com o DataFrame original deliveries_df, right join pelo index
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_normalized_df, how='right', left_index=True, right_index=True)
deliveries_df.reset_index(inplace=True, drop=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat  vehicle_capacity  delivery_size  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              9
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              1
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              7
#
#    delivery_lng  delivery_lat
# 0    -48.116189    -15.848929
# 1    -48.118195    -15.850772
# 2    -48.112483    -15.847871
# 3    -48.118023    -15.846471
# 4    -48.114898    -15.858055

# %% [markdown]
# ## Explorção Schema

# %%
# Dimensão do DataFrame
linhas, colunas = deliveries_df.shape
print(f'O DataFrame possui: {linhas} Linhas e {colunas} Colunas')
# Out:
# O DataFrame possui: 636149 Linhas e 8 Colunas

# %%
# Ver aos tipos de dados no DataFrame
deliveries_df.dtypes
# Out:
# name                 object
# region               object
# hub_lng             float64
# hub_lat             float64
# vehicle_capacity      int64
# delivery_size         int64
# delivery_lng        float64
# delivery_lat        float64
# dtype: object

# %%
# Ver os dados categóricos 'object' do DataFrame
deliveries_df.select_dtypes('object').describe().transpose()
# Out:
#          count unique           top    freq
# name    636149    199  cvrp-1-df-87    5636
# region  636149      3          df-1  304708

# %%
# Ver um resumo estatístico dos dados numéricos.
deliveries_df.describe().transpose()
# Out:
#                      count        mean       std         min         25%  \
# hub_lng           636149.0  -47.949902  0.091875  -48.054989  -48.054989
# hub_lat           636149.0  -15.802359  0.053463  -15.838145  -15.838145
# vehicle_capacity  636149.0  180.000000  0.000000  180.000000  180.000000
# delivery_size     636149.0    5.512111  2.874557    1.000000    3.000000
# delivery_lng      636149.0  -47.946087  0.112769  -48.280779  -48.035911
# delivery_lat      636149.0  -15.809492  0.082462  -16.050028  -15.842795
#
#                          50%         75%         max
# hub_lng           -47.893662  -47.893662  -47.802665
# hub_lat           -15.805118  -15.805118  -15.657014
# vehicle_capacity  180.000000  180.000000  180.000000
# delivery_size       6.000000    8.000000   10.000000
# delivery_lng      -47.928967  -47.883394  -47.310611
# delivery_lat      -15.814033  -15.769516  -15.500355

# %%
# Ver dados estatísticos numéricos do DataFrame
deliveries_df.drop(['name', 'region'], axis=1).select_dtypes('int64').describe().transpose()
# Out:
#                      count        mean       std    min    25%    50%    75%  \
# vehicle_capacity  636149.0  180.000000  0.000000  180.0  180.0  180.0  180.0
# delivery_size     636149.0    5.512111  2.874557    1.0    3.0    6.0    8.0
#
#                     max
# vehicle_capacity  180.0
# delivery_size      10.0

# %%
# Identificar valores nulos
deliveries_df.isna().any()
# Out:
# name                False
# region              False
# hub_lng             False
# hub_lat             False
# vehicle_capacity    False
# delivery_size       False
# delivery_lng        False
# delivery_lat        False
# dtype: bool

# %% [markdown]
# ## 4\. Manipulação

# %% [markdown]
# ## Enriquecimento

# %%
# Selecionando,removendo as duplicatas e ordenando a coluna 'region'
hub_df = deliveries_df[['region','hub_lng', 'hub_lat']]
hub_df = hub_df.drop_duplicates().sort_values(by='region').reset_index(drop=True)
hub_df.head()
# Out:
#   region    hub_lng    hub_lat
# 0   df-0 -47.802665 -15.657014
# 1   df-1 -47.893662 -15.805118
# 2   df-2 -48.054989 -15.838145

# %%
# Visualizando dados sobre uma coordenada Reversa com o Geopandas
geolocator = Nominatim(user_agent="ebac_geocoder")
location = geolocator.reverse("-15.657013854445248, -47.802664728268745")

print(json.dumps(location.raw, indent=2, ensure_ascii=False))
# Out:
# {
#   "place_id": 46082661,
#   "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#   "osm_type": "way",
#   "osm_id": 240210480,
#   "lat": "-15.656916027876347",
#   "lon": "-47.80264463632131",
#   "class": "highway",
#   "type": "secondary",
#   "place_rank": 26,
#   "importance": 0.0533433333333333,
#   "addresstype": "road",
#   "name": "Rua 7",
#   "display_name": "Rua 7, Quadra 2, Sobradinho, Região Geográfica Imediata do Distrito Federal, Região Integrada de Desenvolvimento do Distrito Federal e Entorno, Região Geográfica Intermediária do Distrito Federal, Distrito Federal, Região Centro-Oeste, 73015-127, Brasil",
#   "address": {
#     "road": "Rua 7",
#     "residential": "Quadra 2",
#     "suburb": "Sobradinho",
#     "town": "Sobradinho",
#     "municipality": "Região Geográfica Imediata do Distrito Federal",
#     "county": "Região Integrada de Desenvolvimento do Distrito Federal e Entorno",
# ...

# %%
# Aplicando o limite de resposta para a geocodificação
geocoder = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
# Concatenando as colunas para a geocodificação
hub_df["coordinates"] = hub_df["hub_lat"].astype(str) + ", " + hub_df["hub_lng"].astype(str)
hub_df["geodata"] = hub_df["coordinates"].apply(geocoder)
hub_df.head()
# Out:
#   region    hub_lng    hub_lat                               coordinates  \
# 0   df-0 -47.802665 -15.657014  -15.657013854445248, -47.802664728268745
# 1   df-1 -47.893662 -15.805118    -15.80511751066334, -47.89366206897872
# 2   df-2 -48.054989 -15.838145    -15.83814451122274, -48.05498915846707
#
#                                              geodata
# 0  (Rua 7, Quadra 2, Sobradinho, Região Geográfic...
# 1  (SQS 303, Asa Sul, Brasília, Plano Piloto, Reg...
# 2  (Armazém do Bolo, lote 4/8, CSB 4/5, Taguating...

# %%
# Separando as informações extraidas para cada coluna extraido das coordenadas
hub_geodata_df = pd.json_normalize(hub_df['geodata'].apply(lambda data: data.raw))
hub_geodata_df.head()
# Out:
#    place_id                                            licence osm_type  \
# 0  46082661  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  46676578  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2  43508444  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                  lat                 lon    class         type  \
# 0   240210480  -15.656916027876347  -47.80264463632131  highway    secondary
# 1    66353368  -15.805172753950067  -47.89372354453109  highway  residential
# 2  6249717596          -15.8384371         -48.0552917     shop       pastry
#
#    place_rank  importance  ...     address.state address.ISO3166-2-lvl4  \
# 0          26    0.053343  ...  Distrito Federal                  BR-DF
# 1          26    0.053411  ...  Distrito Federal                  BR-DF
# 2          30    0.000010  ...  Distrito Federal                  BR-DF
#
# ...

# %%
# Renomeando as colunas
hub_geodata_df = hub_geodata_df[["address.town", "address.suburb", "address.city"]]
hub_geodata_df.rename(columns={"address.town": "hub_town", "address.suburb": "hub_suburb", "address.city": "hub_city"}, inplace=True)

# Preenchendo os dados de uma coluna com outra caso houver dado null
hub_geodata_df["hub_city"] = np.where(hub_geodata_df["hub_city"].notna(), hub_geodata_df["hub_city"], hub_geodata_df["hub_town"])
hub_geodata_df["hub_suburb"] = np.where(hub_geodata_df["hub_suburb"].notna(), hub_geodata_df["hub_suburb"], hub_geodata_df["hub_city"])
hub_geodata_df = hub_geodata_df.drop("hub_town", axis=1)
hub_geodata_df.head()
# Out:
#    hub_suburb    hub_city
# 0  Sobradinho  Sobradinho
# 1     Asa Sul    Brasília
# 2  Taguatinga  Taguatinga

# %%
# Mesclando o DataFrame hub_df com o DataFrame hub_geodata_df , pelo index
hub_df = pd.merge(left=hub_df, right=hub_geodata_df, left_index=True, right_index=True)
hub_df = hub_df[["region", "hub_suburb", "hub_city"]]
hub_df.head()
# Out:
#   region  hub_suburb    hub_city
# 0   df-0  Sobradinho  Sobradinho
# 1   df-1     Asa Sul    Brasília
# 2   df-2  Taguatinga  Taguatinga

# %%
# Mesclando o DataFrame hub_df com o DataFrame deliveries_df, inner join pelo index
deliveries_df = pd.merge(left=deliveries_df, right=hub_df, how="inner", on="region")
deliveries_df = deliveries_df[["name", "region", "hub_lng", "hub_lat", "hub_city", "hub_suburb", "vehicle_capacity", "delivery_size", "delivery_lng", "delivery_lat"]]
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055

# %%
# Extraindo as informações do arquivo csv
deliveries_geodata_df = pd.read_csv("deliveries-geodata.csv")
deliveries_geodata_df.head()
# Out:
#    delivery_lng  delivery_lat            delivery_city  \
# 0    -48.116189    -15.848929                Ceilândia
# 1    -48.118195    -15.850772                Ceilândia
# 2    -48.112483    -15.847871                Ceilândia
# 3    -48.118023    -15.846471                Ceilândia
# 4    -48.114898    -15.858055  Sol Nascente/Pôr do Sol
#
#            delivery_suburb
# 0                    P Sul
# 1                    P Sul
# 2                    P Sul
# 3                    P Sul
# 4  Sol Nascente/Pôr do Sol

# %%
# Mesclando o novo DataFrame hub_df com o DataFrame original deliveries_df, inner join pelo index
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_geodata_df[["delivery_city", "delivery_suburb"]], how="inner", left_index=True, right_index=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# ...

# %% [markdown]
# ## Controle de Qualidade

# %%
# Informações gerais do DataFrame
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636149 entries, 0 to 636148
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              636149 non-null  object
#  1   region            636149 non-null  object
#  2   hub_lng           636149 non-null  float64
#  3   hub_lat           636149 non-null  float64
#  4   hub_city          636149 non-null  object
#  5   hub_suburb        636149 non-null  object
#  6   vehicle_capacity  636149 non-null  int64
#  7   delivery_size     636149 non-null  int64
#  8   delivery_lng      636149 non-null  float64
#  9   delivery_lat      636149 non-null  float64
#  10  delivery_city     634447 non-null  object
#  11  delivery_suburb   476264 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 58.2+ MB

# %%
# Validando se possui valores nulos no DataFrame
deliveries_df.isna().any()
# Out:
# name                False
# region              False
# hub_lng             False
# hub_lat             False
# hub_city            False
# hub_suburb          False
# vehicle_capacity    False
# delivery_size       False
# delivery_lng        False
# delivery_lat        False
# delivery_city        True
# delivery_suburb      True
# dtype: bool

# %%
# Calculando a porcentagem de valores nulos no DataFrame das colunas
100 * (deliveries_df["delivery_city"].isna().sum() / len(deliveries_df))
# Out:
# 0.26754738276724477

# %%
100 * (deliveries_df["delivery_suburb"].isna().sum() / len(deliveries_df))
# Out:
# 25.133262804783158

# %%
# Porcentagem de entregas por cidade do maior ao menor
prop_df = deliveries_df[["delivery_city"]].value_counts() / len(deliveries_df)
prop_df.sort_values(ascending=False).head(10)
# Out:
# delivery_city
# Brasília                0.234195
# Taguatinga              0.071625
# Sudoeste / Octogonal    0.069504
# Ceilândia               0.059661
# Águas Claras            0.058293
# Guará                   0.055619
# Lago Sul                0.045620
# Sobradinho              0.045412
# Lago Norte              0.040832
# Gama                    0.034880
# Name: count, dtype: float64

# %%
# Porcentagem de entregas por cidade do maior ao menor
prop_df = deliveries_df[["delivery_suburb"]].value_counts() / len(deliveries_df)
prop_df.sort_values(ascending=False).head(10)
# Out:
# delivery_suburb
# Brasília            0.084564
# Asa Norte           0.076639
# Taguatinga          0.063363
# Asa Sul             0.059263
# Águas Claras        0.056598
# Guará               0.055619
# Samambaia           0.026514
# Sobradinho          0.018148
# Recanto das Emas    0.015029
# P Sul               0.012807
# Name: count, dtype: float64

# %% [markdown]
# ## 5\. Visualização

# %% [markdown]
# ## Visualização I

# %%
# Extraindo as informações do polígono (figura geométrica)
mapa = geopandas.read_file("distrito-federal.shp")
mapa = mapa.loc[[0]]
mapa.head()
# Out:
#                                             geometry
# 0  POLYGON Z ((-47.31048 -16.03602 0.00000, -47.3...

# %%
# Selecionando as colunas e removendo os dados duplicados do DataFrame hub_df
hub_df = deliveries_df[["region", "hub_lng", "hub_lat"]].drop_duplicates().reset_index(drop=True)

# Criando uma nova coluna com coordenadas dentro do polígono
geo_hub_df = geopandas.GeoDataFrame(hub_df, geometry=geopandas.points_from_xy(hub_df["hub_lng"], hub_df["hub_lat"]))
geo_hub_df.head()
# Out:
#   region    hub_lng    hub_lat                     geometry
# 0   df-2 -48.054989 -15.838145  POINT (-48.05499 -15.83814)
# 1   df-1 -47.893662 -15.805118  POINT (-47.89366 -15.80512)
# 2   df-0 -47.802665 -15.657014  POINT (-47.80266 -15.65701)

# %%
# Criando uma nova coluna com coordenadas dentro do polígono na DataFrame geo_deliveries_df
geo_deliveries_df = geopandas.GeoDataFrame(deliveries_df, geometry=geopandas.points_from_xy(deliveries_df["delivery_lng"], deliveries_df["delivery_lat"]))
geo_deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb  \
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# ...

# %%
# Criando o mapa de calor

# Criar o plot
fig, ax = plt.subplots(figsize = (50/2.54, 50/2.54))

# Mapa do distrito
mapa.plot(ax=ax, alpha=0.4, color="lightgrey")

# Plot das entregas
geo_deliveries_df.query("region == 'df-0'").plot(ax=ax, markersize=1, color="blue", label="df-0")
geo_deliveries_df.query("region == 'df-1'").plot(ax=ax, markersize=1, color="black", label="df-1")
geo_deliveries_df.query("region == 'df-2'").plot(ax=ax, markersize=1, color="red", label="df-2")

# Plot dos hubs
geo_hub_df.plot(ax=ax, markersize=30, marker="x", color="black", label="hub")

# Título do plot
plt.title("Entregas no Distrito Federal por Região", fontdict={"fontsize": 16})
lgnd = plt.legend(prop={"size": 15})
for handle in lgnd.legendHandles:
  handle.set_sizes([50])

plt.show()
# Out:
# /tmp/ipykernel_3919/220847420.py:20: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in lgnd.legendHandles:

# %% [markdown]
#  **Insights:**
#  - df-0 e df-2 realizam entregas de pacotes a distâncias maiores de suas hubs em comparação com df-1."
#  - As entregas de df-0 são as mais espalhadas, enquanto as de df-1 são mais concentradas.

# %% [markdown]
# ## Visualização II

# %%
# Extraindo a proporção das colunas selecionadas
data = pd.DataFrame(deliveries_df[['region', 'vehicle_capacity']].value_counts(normalize=True)).reset_index()
data.rename(columns={'proportion': "region_percent"}, inplace=True)
data.head()
# Out:
#   region  vehicle_capacity  region_percent
# 0   df-1               180        0.478988
# 1   df-2               180        0.410783
# 2   df-0               180        0.110229

# %%
print(data.columns)
print(data.head())
# Out:
# Index(['region', 'vehicle_capacity', 'region_percent'], dtype='object')
#   region  vehicle_capacity  region_percent
# 0   df-1               180        0.478988
# 1   df-2               180        0.410783
# 2   df-0               180        0.110229

# %%
# Criando gráfico de barras
with sns.axes_style('whitegrid'):
  grafico = sns.barplot(data=data, x="region", y='region_percent', errorbar=None, palette='Blues_r')
  grafico.set(title='Proporção de Entregas por Região', xlabel='Região', ylabel='Proporção')

# %% [markdown]
#  **Insights:**
#  - df-1 registra o maior número de entregas na região, enquanto df-0 tem o menor.
#  - Existe uma grande diferença na proporção de entregas entre df-0 e as outras regiões.
